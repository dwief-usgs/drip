# %% [markdown]
# # This code documents the data manipulation and processing steps that create DRIP data based off USGS Dam Removal Science Database and American Rivers Dam Removal Database (initial import of data documented in DRIP Data Into Database.ipynb).  This code is a work in progress and will likely change with time.

# %%
import requests
import geopandas as gpd
import json
import geojson
import pandas as pd
import numpy as np
import time
from bis2 import gc2
import re

# %%
damHeight_ft = float(6)
damBuiltYear = int
damRemovedYear = int

# %%
#Retrieves Data for analytical units, Renders GEOJSON as Python object
queryAr = 'https://gc2.datadistillery.org/api/v1/sql/bcb?q=select a._id as id, a.ar_id, a.year_built as arBuilt, a.year_removed as arRemoved, a.dam_height_ft, a.dam_name, a.river, b.featureuri from drip.ardamremoval a left join drip.dripsb b on a.ar_id = b.ar_id' 
rAr = requests.get(url=queryAr,verify=False)
queryDrd = 'https://gc2.datadistillery.org/api/v1/sql/bcb?q=select a._id as id, a.ar_id, a.damyearbuiltoriginalstructure, a.damyearbuiltremovedstructure, a.damyearremovalfinished, a.damheight_m, a.damname, a.damrivername, b.featureuri from drip.drddamremovals a left join drip.dripsb b on a.damaccessionnumber=b.damaccessionnumber'
rDrd = requests.get(url=queryDrd,verify=False)
# Out:
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
arJson = json.loads(rAr.text)
arFeatures = arJson['features']
arData = []
for feature in arFeatures:
    arData.append(feature['properties'])

arDataDf = pd.DataFrame(arData)

# %%
drdJson = json.loads(rDrd.text)
drdFeatures = drdJson['features']
drdData = []
for feature in drdFeatures:
    drdData.append(feature['properties'])
    
drdDataDf = pd.DataFrame(drdData)

# %%
arDataDf
# Out:
#        ar_id                                   arbuilt arremoved  \
# 0     CT-001
# 1     PA-130                                      1875      2007
# 2     PA-202                          Mid-19th Century      2010
# 3     PA-226                                      1740      2011
# 4     VA-015                                                2005
# 5     IL-016                                                2004
# 6     CT-010                                                1995
# 7     VT-005                                                1995
# 8     PA-179                                                2009
# 9     CA-006
# 10    NJ-011                                                2009
# 11    ID-003                                      1935
# 12    VT-020                                     1870s      2014
# 13    PA-224                                                2011
# 14    PA-174                                                2009
# 15    CA-076                                                2010
# 16    IL-021                                                2012
# 17    MI-058                                                2011
# 18    WI-062                                      1870      1998
# 19    ME-027  1796 (original dam at site at this time)      2013
# 20    PA-236                                      1932      2012
# 21    CA-092                               1930s-1950s      2014
# 22    PA-185                                                2009
# 23    PA-242                                     1960s      2013
# 24    PA-258                                     1940s      2014
# 25    ID-019
# 26    WI-077                                                2002
# 27    CT-011                                                1999
# 28    MN-007                                      1872      1999
# 29    WI-115                                                2008
# ...      ...                                       ...       ...
# 1362  VA-006                                                1984
# 1363  MN-018                                      1933      2002
# 1364  CA-001
# 1365  PA-315                                                1968
# 1366  SC-008                                      1970      1999
# 1367  WI-082                                                2002
# 1368  MN-014                                1922, 1989      2001
# 1369  NJ-035                                      1880      2016
# 1370  WA-031                                                2012
# 1371  HI-011
# 1372  SD-013                                                2013
# 1373  PA-317                                                1938
# 1374  NC-010                                                2009
# 1375  OR-033                                                2012
# 1376  HI-017                                      1930      2011
# 1377  NY-029                                      1929      2016
# 1378  AR-001
# 1379  CA-021                                                1949
# 1380  PA-283                                                2015
# 1381  NC-028                                      1960      2016
# 1382  WI-021                                                1982
# 1383  PA-296                                                2015
# 1384  OH-010
# 1385  WI-086                                                2002
# 1386  IL-042                                                2015
# 1387  WY-001
# 1388  PA-005                                                1982
# 1389  HI-018                                      1918      2013
# 1390  MN-010                                      1929      1999
# 1391  MD-004                                                1991
#
#                                           dam_height_ft  \
# 0                                                    17
# 1                                                    16
# 2                                                   3.5
# 3                                                     4
# 4                                                    15
# 5                                                     8
# 6                                                     8
# 7                                                    46
# 8
# 9                                                    10
# 10
# 11                                                   29
# 12                                                   13
# 13
# 14
# 15
# 16                                                    2
# 17
# 18                                                   20
# 19                                                   10
# 20                                                   10
# 21                                                    6
# 22                                                  4.5
# 23                                                    2
# 24                                                   16
# 25                                                   25
# 26
# 27                                                   11
# 28                                                 12.8
# 29                                                   18
# ...                                                 ...
# 1362                                                 12
# 1363                                                  5
# 1364                                                 14
# 1365
# 1366                                                 11
# 1367
# 1368                                                 13
# 1369                                                 17
# 1370
# 1371
# 1372
# 1373
# 1374                                                  3
# 1375  3 (Upstream water surface to downstream water ...
# 1376                                                 16
# 1377                                                 12
# 1378                                                  4
# 1379                                                 14
# 1380                                                  4
# 1381                                                  8
# 1382                                                  2
# 1383
# 1384                                                 30
# 1385
# 1386                                                  3
# 1387
# 1388                                                 12
# 1389                                                 28
# 1390                                                5.3
# 1391
#
#                             dam_name  \
# 0                     John Dee's Dam
# 1                Kehly Run Dam No. 2
# 2                        Smucker Dam
# 3      Unnamed (Right mill race) Dam
# 4                       Rockland Dam
# 5                           YWCA Dam
# 6                 Simpson?s Pond Dam
# 7                   Youngs Brook Dam
# 8                    Axe Factory Dam
# 9                     Salt Creek Dam
# 10                         Seber Dam
# 11                   Buster Lake Dam
# 12                 Kendrick Pond Dam
# 13                   Acheys Mill Dam
# 14                     Conewango Dam
# 15             Fife Creek Check Dam
# 16              Fairbanks Avenue Dam
# 17           Watervliet Spillway Dam
# 18                        Colfax Dam
# 19                  Randall Mill Dam
# 20                    Rakes Pond Dam
# 21                             TCFD7
# 22                   Saucon Park Dam
# 23                  Big Run Park Dam
# 24                    Commodore Dam
# 25              Browns Pond - Cruzen
# 26                         Afton Dam
# 27                      Anaconda Dam
# 28                 Appleton Mill Dam
# 29                    Big Spring Dam
# ...                              ...
# 1362              Adney Gap Pond Dam
# 1363                 Fargo North Dam
# 1364     Big Creek Manufacturing Dam
# 1365              Penns Creek Dam #1
# 1366        I95 Rest Area Lagoon Dam
# 1367          Silver Springs Dam #11
# 1368                   Riverside Dam
# 1369                 Hughesville Dam
# 1370                      Durham Dam
# 1371                  Reservoir 245B
# 1372                    Klondike Dam
# 1373             White Clay Creek #1
# 1374                     Unnamed Dam
# 1375                Ward Dam Removal
# 1376                Kehena Reservoir
# 1377                  Hogansburg Dam
# 1378              Winton Springs Dam
# 1379                        Todd Dam
# 1380                Egypt Quarry Dam
# 1381         Santeetlah Fish Barrier
# 1382                   Schaaf #1 Dam
# 1383     Trexler Nature Preserve Dam
# 1384                     Foxtail Dam
# 1385           Silver Springs Dam #3
# 1386                 Oak Meadows Dam
# 1387  Sheridan Heights Reservoir Dam
# 1388            Upper Friendship Dam
# 1389             Wahikuli Reservoir
# 1390                     Midtown Dam
# 1391         Bacon Ridge Branch Weir
#
#                                              featureuri  \
# 0     https://www.sciencebase.gov/catalog/item/566b3...
# 1     https://www.sciencebase.gov/catalog/item/55fb4...
# 2     https://www.sciencebase.gov/catalog/item/55fb4...
# 3     https://www.sciencebase.gov/catalog/item/55fb4...
# 4     https://www.sciencebase.gov/catalog/item/55fb4...
# 5     https://www.sciencebase.gov/catalog/item/55fb4...
# 6     https://www.sciencebase.gov/catalog/item/55fb4...
# 7     https://www.sciencebase.gov/catalog/item/566b3...
# 8     https://www.sciencebase.gov/catalog/item/55fb4...
# 9     https://www.sciencebase.gov/catalog/item/55fb4...
# 10    https://www.sciencebase.gov/catalog/item/55fb4...
# 11    https://www.sciencebase.gov/catalog/item/566b3...
# 12    https://www.sciencebase.gov/catalog/item/55fb4...
# 13    https://www.sciencebase.gov/catalog/item/55fb4...
# 14    https://www.sciencebase.gov/catalog/item/55fb4...
# 15    https://www.sciencebase.gov/catalog/item/55fb4...
# 16    https://www.sciencebase.gov/catalog/item/55fb4...
# 17    https://www.sciencebase.gov/catalog/item/55fb4...
# 18    https://www.sciencebase.gov/catalog/item/566b3...
# 19    https://www.sciencebase.gov/catalog/item/55fb4...
# 20    https://www.sciencebase.gov/catalog/item/55fb4...
# 21    https://www.sciencebase.gov/catalog/item/55fb4...
# 22    https://www.sciencebase.gov/catalog/item/55fb4...
# 23    https://www.sciencebase.gov/catalog/item/55fb4...
# 24    https://www.sciencebase.gov/catalog/item/55fb4...
# 25    https://www.sciencebase.gov/catalog/item/566b3...
# 26    https://www.sciencebase.gov/catalog/item/55fb4...
# 27    https://www.sciencebase.gov/catalog/item/55fb4...
# 28    https://www.sciencebase.gov/catalog/item/55fb4...
# 29    https://www.sciencebase.gov/catalog/item/55fb4...
# ...                                                 ...
# 1362                                               None
# 1363                                               None
# 1364                                               None
# 1365                                               None
# 1366                                               None
# 1367                                               None
# 1368                                               None
# 1369                                               None
# 1370                                               None
# 1371                                               None
# 1372                                               None
# 1373                                               None
# 1374                                               None
# 1375                                               None
# 1376                                               None
# 1377                                               None
# 1378                                               None
# 1379                                               None
# 1380                                               None
# 1381                                               None
# 1382                                               None
# 1383                                               None
# 1384                                               None
# 1385                                               None
# 1386                                               None
# 1387                                               None
# 1388                                               None
# 1389                                               None
# 1390                                               None
# 1391                                               None
#
#                                         id  \
# 0     80fcb8f0-55f7-484e-ba2f-4d948c7410df
# 1     216594ae-d722-49b4-be02-52c2863eed2d
# 2     d6a04165-f655-444d-8cda-1045ff8eac9f
# 3     40fc75ca-0a1f-45a5-b750-36a9c862edec
# 4     61960a99-40b9-4555-81f0-41039a2abb74
# 5     9bfe6154-e118-4ead-ba89-648c822c3e67
# 6     683b0691-6f66-41ff-b03d-3ca5cc995282
# 7     fff3613f-a1a2-4919-9d6f-727d06e2ade1
# 8     3585fed1-a69a-408c-97eb-c5c0a5fd3a3e
# 9     dbe0d2a7-db7f-4313-9ba0-8de199d57c1a
# 10    03dbfaf1-6def-4b0c-b90b-f3e770124009
# 11    4858770f-f8e5-43b3-b012-ad05dcb8ab5d
# 12    583327eb-be3a-4bb3-b0db-8d036fc875ce
# 13    d332a016-0f5b-4229-906a-af4592e33c08
# 14    d6d02db9-2ab5-4811-9337-1bd4df385a9a
# 15    de65034d-e4f9-47d8-871c-3ed0263a8219
# 16    8435662a-bb63-49d9-83f5-cef8890f696c
# 17    611e8fca-7145-4ee4-8d68-d37ba8a26dd5
# 18    6ba53129-4687-4735-8039-dd576cc3fa55
# 19    24878cc0-36d3-4572-8bb8-0c695e748b79
# 20    84899567-b5b8-4ea1-906c-864751ad405c
# 21    99cddd2b-a292-4883-a39a-c1a9f0404524
# 22    4c2af7a0-55be-4a69-89a5-fc07d4e679dd
# 23    717f2cdd-7e8b-42de-9a95-9f14c5872d03
# 24    ce3ef3ef-0286-429d-b69b-76a5274dce8e
# 25    6951b734-26fd-4429-b920-484be444dbc1
# 26    8c9903b1-294b-471f-97f4-4e3f82fe8d17
# 27    002737fa-e7ff-4e82-b81e-196b6f27ac81
# 28    c44387ac-4006-4887-befd-0e41e4159ac6
# 29    baaab623-1a4b-42d1-a0a2-27f1b2716c1f
# ...                                    ...
# 1362  38244b2e-ed5d-4042-b1db-257d577bb5d3
# 1363  b9a15fbb-2707-4de7-b763-6e7c41295b04
# 1364  aa23359a-4a5a-485a-a0aa-84251dd226d3
# 1365  6478ebe1-882a-40c0-bea1-134fcb5ab6eb
# 1366  1e60121d-8f61-4211-8058-8f47077bf6df
# 1367  fe1c5d66-c144-40fd-9e8f-eed1a4f52a95
# 1368  23090335-6787-4ea6-9483-79326ac10f1b
# 1369  1f2ec126-6be5-4168-adb0-17594743d26c
# 1370  a04c8c18-03fa-49e8-bc63-28ebba0d2623
# 1371  286f1756-f97e-475a-80a3-70214bcdd902
# 1372  01e39735-2f55-42c9-8f9a-58c747f7ed22
# 1373  e71d20b4-7672-4794-be43-f46d6ebc5f31
# 1374  6b0e628a-b157-4555-a383-3d99c3fd4d21
# 1375  b269f0f4-ae3d-411d-a9c6-2b8bcffdaf80
# 1376  965716bd-154b-4616-be73-de793247623c
# 1377  620a465d-3b79-4de7-b090-36fa4a5a3fe1
# 1378  f69135fd-b052-4324-8727-0803c228ddcc
# 1379  0f82f6df-a29c-4b77-a1d0-4b5d0b1bc01f
# 1380  860c9253-6524-4564-96e8-88c2aff3e05a
# 1381  e16027fc-5c0a-4e2d-a645-61764f72bf03
# 1382  c3762ec4-75f2-49b9-b37a-4582308593f7
# 1383  bf77ac67-d405-4cb0-9a6a-92478ba7c158
# 1384  60626b73-d86c-4047-a784-937735c8ee87
# 1385  340ab455-8b3e-4328-aa69-b8f556262bc3
# 1386  48d5868c-c527-4185-94b5-3af179a695db
# 1387  cfa9fff5-0918-44fc-92e7-0d8aca878312
# 1388  e73f62b1-fa23-478e-92b1-ce0e70b2d3d6
# 1389  00028048-1572-4557-9af7-a0c4d5c5b89e
# 1390  33ff3569-bbb4-422c-8b5e-fc8a95684da3
# 1391  9d976ef9-490e-4955-89e7-5bf1c2610de5
#
#                                         river
# 0                                   Mad River
# 1                                   Kehly Run
# 2                                   Groff Run
# 3                Tributary to Yellow Breeches
# 4              Shenandoah River Middle Branch
# 5                              Brewster Creek
# 6                               Wharton Brook
# 7                                Youngs Brook
# 8                               Fishing Creek
# 9                                  Salt Creek
# 10                         Musconetcong River
# 11                               Garden Creek
# 12                         Sugar Hollow Brook
# 13                                Unami Creek
# 14                            Conewango Creek
# 15                                 Fife Creek
# 16                          Des Plaines River
# 17                              Paw Paw River
# 18                        Eighteen Mile Creek
# 19          Chandler Brook (Royal River trib)
# 20                                 Pond Creek
# 21                              Trabuco Creek
# 22                               Saucon Creek
# 23                                    Big Run
# 24                                  Hinty Run
# 25                                  Lake Fork
# 26                                 Bass Creek
# 27                            Naugatuck River
# 28                       Pomme de Terre River
# 29                           Big Spring Creek
# ...                                       ...
# 1362
# 1363                   Red River of the North
# 1364                                Big Creek
# 1365                              Penns Creek
# 1366                 Tributary to Black Creek
# 1367                 Tributary to Onion River
# 1368                                Red River
# 1369                       Musconetcong River
# 1370                          Toppenish Creek
# 1371
# 1372                          Big Sioux River
# 1373             East Branch White Clay Creek
# 1374                               Sims Creek
# 1375                              Mckay Creek
# 1376                                  Wainaia
# 1377                        Saint Regis River
# 1378
# 1379  Trinity River (East Fork of North Fork)
# 1380                             Coplay Creek
# 1381                               Santeetlah
# 1382
# 1383                             Jordan Creek
# 1384
# 1385                 Tributary to Onion River
# 1386                               Salt Creek
# 1387            Tributary in City of Sheridan
# 1388
# 1389                          Honokohau Ditch
# 1390                   Red River of the North
# 1391                       Bacon Ridge Branch
#
# [1392 rows x 8 columns]

# %%
arInDrd = drdDataDf['ar_id'].dropna().tolist()
arInDrd = list(filter(None, arInDrd)) # removes empty str from list

# %%
#This cell cleans american rivers data.  For example string characters are removed from integar fields
arClean = []

for row in arDataDf.itertuples():
    identifier = row.id
    ar_id = row.ar_id
    
    #set dam height
    height = row.dam_height_ft 
    if height == 0:
        damHeight_ft = None
    elif not height:
        damHeight_ft = None
    else:
        if '~' in height:
            height = re.sub('~','', height)
        try:
            damHeight_ft = float(height)
        except:
            damHeight_ft = None
            
    #set year built
    built = row.arbuilt
    if built == 0:
        damBuiltYear = None
    elif not built:
        damBuiltYear = None
    else:
        if '~' in built:
            built = re.sub('~','', built)
        if 's' in built:
            built = re.sub('s','', built)
        try:
            damBuiltYear = int(built)
        except:
            damBuiltYear = None
    
    #set year removed
    removed = row.arremoved
    if removed == 0:
        damRemovedYear = None
    elif not removed:
        damRemovedYear = None
    else:
        if '~' in removed:
            removed = re.sub('~','', removed)
        if 's' in removed:
            removed = re.sub('s','', removed)
        try:
            damRemovedYear = int(removed)
        except:
            damRemovedYear = None
            
    #set dam name and stream name
    #Need to deal with this dam name : damSong of the Morning Ranch Dam (Golden Lotus Dam; Lansing Club Dam)'
    dam_name = row.dam_name
    dam_name = dam_name.replace("'",'')
    dam_name = dam_name.replace('&','and')
    #These alternate names for one dam in the dam name field are causing issues in insert so I am dropping them
    dam_name = dam_name.replace("(Golden Lotus Dam; Lansing Club Dam)",'')
    
    stream_name = row.river
    stream_name = stream_name.replace("'",'')
    
    inDrd = 0
    
    dam_uri = row.featureuri

    arClean.append({'identifier': identifier, 'ar_id': ar_id, 'damBuiltYear': damBuiltYear, 'damRemovedYear': damRemovedYear, 'damHeight_ft': damHeight_ft, 'dam_name':dam_name, 'stream_name':stream_name, 'inDrd':inDrd, 'dam_uri': dam_uri})      

arCleanDf = pd.DataFrame(arClean)

# %%
drdClean = []

for row in drdDataDf.itertuples():
    
    #identifier
    identifier = row.id
    ar_id = row.ar_id
    #Convert meters to feet
    height = row.damheight_m
    if (height == 0 or not height) and ar_id in arInDrd:  #Ensure no zero values
        record = arCleanDf.loc[arCleanDf['ar_id'] == ar_id]
        try:
            damHeight_ft = float(record['damHeight_ft'])
        except:
            damHeight_ft = None
    elif height == 0 or not height:  #Ensure no zero values
        damHeight_ft = None
    elif height:
        damHeight_ft = float(height) * 3.28084   #convert meters to feet
    else:
        damHeight_ft = height
    
    #Combine Year Built fields
    built = row.damyearbuiltremovedstructure
    builtorig = row.damyearbuiltoriginalstructure
    if (built == 0 or not built) and ar_id in arInDrd:
        if builtorig and builtorig != 0:
            try:
                damBuiltYear = int(builtorig)
            except:
                record = arCleanDf.loc[arCleanDf['ar_id'] == ar_id]
                try:
                    damBuiltYear = int(record['damBuiltYear'])
                except:
                    damBuiltYear = None
    elif (built == 0 or not built):
        damBuiltYear = None
    else:
        try:
            damBuiltYear = int(built)
        except:
            damBuiltYear = None
        
    #Year Removed 
    removed = row.damyearremovalfinished
    if (removed == 0 or not removed) and ar_id in arInDrd:
        record = arCleanDf.loc[arCleanDf['ar_id'] == ar_id]
        try:
            damRemovedYear = int(record['damRemovedYear'])
        except:
            damRemovedYear = None
    elif removed == 0 or not removed:
        damRemovedYear = None
    else:
        try:
            damRemovedYear = int(removed)
        except:
            damRemovedYear = None
    
    #Set dam_name, stream_name, and dam_uri
    #Might want to add complexity here, if dam doesn't have dam_name use ardf
    dam_name = row.damname
    dam_name = dam_name.replace("'",'')
    dam_name = dam_name.replace('&','and')
    
    stream_name = row.damrivername
    stream_name = stream_name.replace("'",'')
    
    dam_uri = row.featureuri
    inDrd = 1
    
    drdClean.append({'identifier': identifier, 'ar_id': ar_id, 'damBuiltYear': damBuiltYear, 'damRemovedYear': damRemovedYear, 'damHeight_ft': damHeight_ft, 'dam_name':dam_name, 'stream_name':stream_name, 'dam_uri':dam_uri, 'inDrd':inDrd})

drdCleanDf = pd.DataFrame(drdClean)

# %% [markdown]
# ### The next several cells are in place to manually verify table sizes coming out of AR and DRD cleaning and the combination of the two tables

# %%
drdCleanDf.shape
# Out:
# (170, 9)

# %%
arCleanDf.shape
# Out:
# (1392, 9)

# %%
for ar in arInDrd:
    arCleanDf = arCleanDf[arCleanDf['ar_id'].isin([ar])== False]

# %%
 arCleanDf.shape
# Out:
# (1257, 9)

# %%
len(arInDrd)
# Out:
# 135

# %%
#Make sure length of arInDrd plus ar data shape adds up to initial ar shape
1257+135
# Out:
# 1392

# %%
arCleanDf
# Out:
#        ar_id  damBuiltYear  damHeight_ft  damRemovedYear  \
# 0     CT-001           NaN          17.0             NaN
# 1     PA-130        1875.0          16.0          2007.0
# 2     PA-202           NaN           3.5          2010.0
# 3     PA-226        1740.0           4.0          2011.0
# 4     VA-015           NaN          15.0          2005.0
# 6     CT-010           NaN           8.0          1995.0
# 7     VT-005           NaN          46.0          1995.0
# 8     PA-179           NaN           NaN          2009.0
# 9     CA-006           NaN          10.0             NaN
# 10    NJ-011           NaN           NaN          2009.0
# 11    ID-003        1935.0          29.0             NaN
# 12    VT-020        1870.0          13.0          2014.0
# 13    PA-224           NaN           NaN          2011.0
# 14    PA-174           NaN           NaN          2009.0
# 15    CA-076           NaN           NaN          2010.0
# 16    IL-021           NaN           2.0          2012.0
# 17    MI-058           NaN           NaN          2011.0
# 18    WI-062        1870.0          20.0          1998.0
# 19    ME-027           NaN          10.0          2013.0
# 20    PA-236        1932.0          10.0          2012.0
# 21    CA-092           NaN           6.0          2014.0
# 22    PA-185           NaN           4.5          2009.0
# 23    PA-242        1960.0           2.0          2013.0
# 24    PA-258        1940.0          16.0          2014.0
# 25    ID-019           NaN          25.0             NaN
# 40    IL-024           NaN           3.0          2005.0
# 49    OH-048        1930.0           6.0          2012.0
# 55    OH-056           NaN          20.0          2014.0
# 56    OH-057           NaN          15.0          2014.0
# 64    OH-053           NaN           NaN          2013.0
# ...      ...           ...           ...             ...
# 1360  HI-005           NaN          21.0             NaN
# 1361  CT-006           NaN           8.0          1992.0
# 1362  VA-006           NaN          12.0          1984.0
# 1363  MN-018        1933.0           5.0          2002.0
# 1364  CA-001           NaN          14.0             NaN
# 1366  SC-008        1970.0          11.0          1999.0
# 1367  WI-082           NaN           NaN          2002.0
# 1368  MN-014           NaN          13.0          2001.0
# 1369  NJ-035        1880.0          17.0          2016.0
# 1370  WA-031           NaN           NaN          2012.0
# 1371  HI-011           NaN           NaN             NaN
# 1372  SD-013           NaN           NaN          2013.0
# 1374  NC-010           NaN           3.0          2009.0
# 1375  OR-033           NaN           NaN          2012.0
# 1376  HI-017        1930.0          16.0          2011.0
# 1377  NY-029        1929.0          12.0          2016.0
# 1378  AR-001           NaN           4.0             NaN
# 1379  CA-021           NaN          14.0          1949.0
# 1380  PA-283           NaN           4.0          2015.0
# 1381  NC-028        1960.0           8.0          2016.0
# 1382  WI-021           NaN           2.0          1982.0
# 1383  PA-296           NaN           NaN          2015.0
# 1384  OH-010           NaN          30.0             NaN
# 1385  WI-086           NaN           NaN          2002.0
# 1386  IL-042           NaN           3.0          2015.0
# 1387  WY-001           NaN           NaN             NaN
# 1388  PA-005           NaN          12.0          1982.0
# 1389  HI-018        1918.0          28.0          2013.0
# 1390  MN-010        1929.0           5.3          1999.0
# 1391  MD-004           NaN           NaN          1991.0
#
#                             dam_name  \
# 0                      John Dees Dam
# 1                Kehly Run Dam No. 2
# 2                        Smucker Dam
# 3      Unnamed (Right mill race) Dam
# 4                       Rockland Dam
# 6                 Simpson?s Pond Dam
# 7                   Youngs Brook Dam
# 8                    Axe Factory Dam
# 9                     Salt Creek Dam
# 10                         Seber Dam
# 11                   Buster Lake Dam
# 12                 Kendrick Pond Dam
# 13                   Acheys Mill Dam
# 14                     Conewango Dam
# 15             Fife Creek Check Dam
# 16              Fairbanks Avenue Dam
# 17           Watervliet Spillway Dam
# 18                        Colfax Dam
# 19                  Randall Mill Dam
# 20                    Rakes Pond Dam
# 21                             TCFD7
# 22                   Saucon Park Dam
# 23                  Big Run Park Dam
# 24                    Commodore Dam
# 25              Browns Pond - Cruzen
# 40               DeSantos Dam/Arnold
# 49                   German Farm Dam
# 55                       Harpham Dam
# 56                   Heart Break Dam
# 64            LeFever Powerhouse Dam
# ...                              ...
# 1360                  Reservoir 410B
# 1361                  Muddy Pond Dam
# 1362              Adney Gap Pond Dam
# 1363                 Fargo North Dam
# 1364     Big Creek Manufacturing Dam
# 1366        I95 Rest Area Lagoon Dam
# 1367          Silver Springs Dam #11
# 1368                   Riverside Dam
# 1369                 Hughesville Dam
# 1370                      Durham Dam
# 1371                  Reservoir 245B
# 1372                    Klondike Dam
# 1374                     Unnamed Dam
# 1375                Ward Dam Removal
# 1376                Kehena Reservoir
# 1377                  Hogansburg Dam
# 1378              Winton Springs Dam
# 1379                        Todd Dam
# 1380                Egypt Quarry Dam
# 1381         Santeetlah Fish Barrier
# 1382                   Schaaf #1 Dam
# 1383     Trexler Nature Preserve Dam
# 1384                     Foxtail Dam
# 1385           Silver Springs Dam #3
# 1386                 Oak Meadows Dam
# 1387  Sheridan Heights Reservoir Dam
# 1388            Upper Friendship Dam
# 1389             Wahikuli Reservoir
# 1390                     Midtown Dam
# 1391         Bacon Ridge Branch Weir
#
#                                                 dam_uri  \
# 0     https://www.sciencebase.gov/catalog/item/566b3...
# 1     https://www.sciencebase.gov/catalog/item/55fb4...
# 2     https://www.sciencebase.gov/catalog/item/55fb4...
# 3     https://www.sciencebase.gov/catalog/item/55fb4...
# 4     https://www.sciencebase.gov/catalog/item/55fb4...
# 6     https://www.sciencebase.gov/catalog/item/55fb4...
# 7     https://www.sciencebase.gov/catalog/item/566b3...
# 8     https://www.sciencebase.gov/catalog/item/55fb4...
# 9     https://www.sciencebase.gov/catalog/item/55fb4...
# 10    https://www.sciencebase.gov/catalog/item/55fb4...
# 11    https://www.sciencebase.gov/catalog/item/566b3...
# 12    https://www.sciencebase.gov/catalog/item/55fb4...
# 13    https://www.sciencebase.gov/catalog/item/55fb4...
# 14    https://www.sciencebase.gov/catalog/item/55fb4...
# 15    https://www.sciencebase.gov/catalog/item/55fb4...
# 16    https://www.sciencebase.gov/catalog/item/55fb4...
# 17    https://www.sciencebase.gov/catalog/item/55fb4...
# 18    https://www.sciencebase.gov/catalog/item/566b3...
# 19    https://www.sciencebase.gov/catalog/item/55fb4...
# 20    https://www.sciencebase.gov/catalog/item/55fb4...
# 21    https://www.sciencebase.gov/catalog/item/55fb4...
# 22    https://www.sciencebase.gov/catalog/item/55fb4...
# 23    https://www.sciencebase.gov/catalog/item/55fb4...
# 24    https://www.sciencebase.gov/catalog/item/55fb4...
# 25    https://www.sciencebase.gov/catalog/item/566b3...
# 40    https://www.sciencebase.gov/catalog/item/55fb4...
# 49    https://www.sciencebase.gov/catalog/item/55fb4...
# 55    https://www.sciencebase.gov/catalog/item/55fb4...
# 56    https://www.sciencebase.gov/catalog/item/55fb4...
# 64    https://www.sciencebase.gov/catalog/item/55fb4...
# ...                                                 ...
# 1360                                               None
# 1361                                               None
# 1362                                               None
# 1363                                               None
# 1364                                               None
# 1366                                               None
# 1367                                               None
# 1368                                               None
# 1369                                               None
# 1370                                               None
# 1371                                               None
# 1372                                               None
# 1374                                               None
# 1375                                               None
# 1376                                               None
# 1377                                               None
# 1378                                               None
# 1379                                               None
# 1380                                               None
# 1381                                               None
# 1382                                               None
# 1383                                               None
# 1384                                               None
# 1385                                               None
# 1386                                               None
# 1387                                               None
# 1388                                               None
# 1389                                               None
# 1390                                               None
# 1391                                               None
#
#                                 identifier  inDrd  \
# 0     80fcb8f0-55f7-484e-ba2f-4d948c7410df      0
# 1     216594ae-d722-49b4-be02-52c2863eed2d      0
# 2     d6a04165-f655-444d-8cda-1045ff8eac9f      0
# 3     40fc75ca-0a1f-45a5-b750-36a9c862edec      0
# 4     61960a99-40b9-4555-81f0-41039a2abb74      0
# 6     683b0691-6f66-41ff-b03d-3ca5cc995282      0
# 7     fff3613f-a1a2-4919-9d6f-727d06e2ade1      0
# 8     3585fed1-a69a-408c-97eb-c5c0a5fd3a3e      0
# 9     dbe0d2a7-db7f-4313-9ba0-8de199d57c1a      0
# 10    03dbfaf1-6def-4b0c-b90b-f3e770124009      0
# 11    4858770f-f8e5-43b3-b012-ad05dcb8ab5d      0
# 12    583327eb-be3a-4bb3-b0db-8d036fc875ce      0
# 13    d332a016-0f5b-4229-906a-af4592e33c08      0
# 14    d6d02db9-2ab5-4811-9337-1bd4df385a9a      0
# 15    de65034d-e4f9-47d8-871c-3ed0263a8219      0
# 16    8435662a-bb63-49d9-83f5-cef8890f696c      0
# 17    611e8fca-7145-4ee4-8d68-d37ba8a26dd5      0
# 18    6ba53129-4687-4735-8039-dd576cc3fa55      0
# 19    24878cc0-36d3-4572-8bb8-0c695e748b79      0
# 20    84899567-b5b8-4ea1-906c-864751ad405c      0
# 21    99cddd2b-a292-4883-a39a-c1a9f0404524      0
# 22    4c2af7a0-55be-4a69-89a5-fc07d4e679dd      0
# 23    717f2cdd-7e8b-42de-9a95-9f14c5872d03      0
# 24    ce3ef3ef-0286-429d-b69b-76a5274dce8e      0
# 25    6951b734-26fd-4429-b920-484be444dbc1      0
# 40    d0a83067-ce1a-461d-b0ef-1c13974ba5bf      0
# 49    cf80bd55-5e9a-4a1d-b5c8-cbe222b8abb1      0
# 55    80f26cc1-b7e6-4181-9e2c-0eb52ca5671b      0
# 56    7545bfb5-329f-4d5c-b797-3bad4403d9b6      0
# 64    135dc990-2132-4c60-937f-637f0933a4df      0
# ...                                    ...    ...
# 1360  35fb536f-079b-41c9-8dd5-e7da030a65cf      0
# 1361  397b41f3-e9be-4a24-8fa2-4893b052547a      0
# 1362  38244b2e-ed5d-4042-b1db-257d577bb5d3      0
# 1363  b9a15fbb-2707-4de7-b763-6e7c41295b04      0
# 1364  aa23359a-4a5a-485a-a0aa-84251dd226d3      0
# 1366  1e60121d-8f61-4211-8058-8f47077bf6df      0
# 1367  fe1c5d66-c144-40fd-9e8f-eed1a4f52a95      0
# 1368  23090335-6787-4ea6-9483-79326ac10f1b      0
# 1369  1f2ec126-6be5-4168-adb0-17594743d26c      0
# 1370  a04c8c18-03fa-49e8-bc63-28ebba0d2623      0
# 1371  286f1756-f97e-475a-80a3-70214bcdd902      0
# 1372  01e39735-2f55-42c9-8f9a-58c747f7ed22      0
# 1374  6b0e628a-b157-4555-a383-3d99c3fd4d21      0
# 1375  b269f0f4-ae3d-411d-a9c6-2b8bcffdaf80      0
# 1376  965716bd-154b-4616-be73-de793247623c      0
# 1377  620a465d-3b79-4de7-b090-36fa4a5a3fe1      0
# 1378  f69135fd-b052-4324-8727-0803c228ddcc      0
# 1379  0f82f6df-a29c-4b77-a1d0-4b5d0b1bc01f      0
# 1380  860c9253-6524-4564-96e8-88c2aff3e05a      0
# 1381  e16027fc-5c0a-4e2d-a645-61764f72bf03      0
# 1382  c3762ec4-75f2-49b9-b37a-4582308593f7      0
# 1383  bf77ac67-d405-4cb0-9a6a-92478ba7c158      0
# 1384  60626b73-d86c-4047-a784-937735c8ee87      0
# 1385  340ab455-8b3e-4328-aa69-b8f556262bc3      0
# 1386  48d5868c-c527-4185-94b5-3af179a695db      0
# 1387  cfa9fff5-0918-44fc-92e7-0d8aca878312      0
# 1388  e73f62b1-fa23-478e-92b1-ce0e70b2d3d6      0
# 1389  00028048-1572-4557-9af7-a0c4d5c5b89e      0
# 1390  33ff3569-bbb4-422c-8b5e-fc8a95684da3      0
# 1391  9d976ef9-490e-4955-89e7-5bf1c2610de5      0
#
#                                   stream_name
# 0                                   Mad River
# 1                                   Kehly Run
# 2                                   Groff Run
# 3                Tributary to Yellow Breeches
# 4              Shenandoah River Middle Branch
# 6                               Wharton Brook
# 7                                Youngs Brook
# 8                               Fishing Creek
# 9                                  Salt Creek
# 10                         Musconetcong River
# 11                               Garden Creek
# 12                         Sugar Hollow Brook
# 13                                Unami Creek
# 14                            Conewango Creek
# 15                                 Fife Creek
# 16                          Des Plaines River
# 17                              Paw Paw River
# 18                        Eighteen Mile Creek
# 19          Chandler Brook (Royal River trib)
# 20                                 Pond Creek
# 21                              Trabuco Creek
# 22                               Saucon Creek
# 23                                    Big Run
# 24                                  Hinty Run
# 25                                  Lake Fork
# 40                             Brewster Creek
# 49                             Auglaize River
# 55        Unnamed tributary to Cuyahoga River
# 56        Unnamed tributary to Cuyahoga River
# 64                             Cuyahoga River
# ...                                       ...
# 1360
# 1361                              Muddy Brook
# 1362
# 1363                   Red River of the North
# 1364                                Big Creek
# 1366                 Tributary to Black Creek
# 1367                 Tributary to Onion River
# 1368                                Red River
# 1369                       Musconetcong River
# 1370                          Toppenish Creek
# 1371
# 1372                          Big Sioux River
# 1374                               Sims Creek
# 1375                              Mckay Creek
# 1376                                  Wainaia
# 1377                        Saint Regis River
# 1378
# 1379  Trinity River (East Fork of North Fork)
# 1380                             Coplay Creek
# 1381                               Santeetlah
# 1382
# 1383                             Jordan Creek
# 1384
# 1385                 Tributary to Onion River
# 1386                               Salt Creek
# 1387            Tributary in City of Sheridan
# 1388
# 1389                          Honokohau Ditch
# 1390                   Red River of the North
# 1391                       Bacon Ridge Branch
#
# [1257 rows x 9 columns]

# %%
#Append AR dams(not including those in USGS database) to USGS database
dripDf = drdCleanDf.append(arCleanDf)

# %%
dripDf.shape
# Out:
# (1427, 9)

# %%
dripDf
# Out:
#        ar_id  damBuiltYear  damHeight_ft  damRemovedYear  \
# 0     WI-077        1952.0      8.858268          1996.0
# 1     CT-011        1750.0     11.154856          1999.0
# 2     MN-007        1872.0     17.060368          1999.0
# 3     WI-115        1900.0     11.154856          2008.0
# 4     PA-309        1900.0           NaN          1916.0
# 5     WI-006        1851.0     14.000000          2012.0
# 6     WI-096        1955.0      8.202100          2003.0
# 7     WI-095        1955.0      3.280840          2003.0
# 8     WI-054        1851.0     12.000000          1996.0
# 9     OR-017        1965.0      8.202100          2007.0
# 10    NC-007        1921.0     16.404200          2006.0
# 11    PA-024        1921.0     10.170604          1997.0
# 12    NC-003        1945.0      6.889764          1998.0
# 13    OR-022        1914.0     11.154856          2008.0
# 14    OR-027        1913.0    124.671920          2012.0
# 15    WI-004        1856.0      8.858268          1960.0
# 16    FL-001        1960.0     21.981628          1989.0
# 17    IL-016        1929.0      7.874016          2004.0
# 18    MI-039        1932.0      7.874016          2008.0
# 19    NC-015        1913.0     12.139108          2010.0
# 20    OR-014        1925.0     10.498688          2003.0
# 21    CA-102        1931.0           NaN          2011.0
# 22    PA-311        1855.0     13.123360          1985.0
# 23    ME-005        1837.0     39.370080          1999.0
# 24    WA-013        1912.0    104.986880          2012.0
# 25    VA-013        1910.0     21.981628          2005.0
# 26    NY-010        1913.0      9.842520          2009.0
# 27    AZ-004        1909.0     26.246720          2008.0
# 28    PA-044        1909.0           NaN          2000.0
# 29    MN-006        1923.0     19.028872          1999.0
# ...      ...           ...           ...             ...
# 1360  HI-005           NaN     21.000000             NaN
# 1361  CT-006           NaN      8.000000          1992.0
# 1362  VA-006           NaN     12.000000          1984.0
# 1363  MN-018        1933.0      5.000000          2002.0
# 1364  CA-001           NaN     14.000000             NaN
# 1366  SC-008        1970.0     11.000000          1999.0
# 1367  WI-082           NaN           NaN          2002.0
# 1368  MN-014           NaN     13.000000          2001.0
# 1369  NJ-035        1880.0     17.000000          2016.0
# 1370  WA-031           NaN           NaN          2012.0
# 1371  HI-011           NaN           NaN             NaN
# 1372  SD-013           NaN           NaN          2013.0
# 1374  NC-010           NaN      3.000000          2009.0
# 1375  OR-033           NaN           NaN          2012.0
# 1376  HI-017        1930.0     16.000000          2011.0
# 1377  NY-029        1929.0     12.000000          2016.0
# 1378  AR-001           NaN      4.000000             NaN
# 1379  CA-021           NaN     14.000000          1949.0
# 1380  PA-283           NaN      4.000000          2015.0
# 1381  NC-028        1960.0      8.000000          2016.0
# 1382  WI-021           NaN      2.000000          1982.0
# 1383  PA-296           NaN           NaN          2015.0
# 1384  OH-010           NaN     30.000000             NaN
# 1385  WI-086           NaN           NaN          2002.0
# 1386  IL-042           NaN      3.000000          2015.0
# 1387  WY-001           NaN           NaN             NaN
# 1388  PA-005           NaN     12.000000          1982.0
# 1389  HI-018        1918.0     28.000000          2013.0
# 1390  MN-010        1929.0      5.300000          1999.0
# 1391  MD-004           NaN           NaN          1991.0
#
#                             dam_name  \
# 0                          Afton Dam
# 1                       Anaconda Dam
# 2                       Appleton Dam
# 3                     Big Spring Dam
# 4                   Big Spring Run 1
# 5                    Black Earth Dam
# 6          Boulder Creek "lower dam"
# 7          Boulder Creek "upper dam"
# 8                    Bowen Mills Dam
# 9                    Brownsville Dam
# 10                     Carbonton Dam
# 11                   Castle Finn Dam
# 12               Cherry Hospital Dam
# 13                     Chiloquin Dam
# 14                        Condit Dam
# 15                  Cross Plains Dam
# 16                     Dead Lake Dam
# 17     Brewster Creek Dam (YWCA Dam)
# 18                        Dexter Dam
# 19                     Dillsboro Dam
# 20                  Dinner Creek Dam
# 21                    Dream Lake Dam
# 22                 Eaton-Dikeman Dam
# 23                       Edwards Dam
# 24                         Elwha Dam
# 25                        Embrey Dam
# 26                Fort Covington Dam
# 27                  Fossil Creek Dam
# 28                Franklin Mills Dam
# 29                        Frazee Dam
# ...                              ...
# 1360                  Reservoir 410B
# 1361                  Muddy Pond Dam
# 1362              Adney Gap Pond Dam
# 1363                 Fargo North Dam
# 1364     Big Creek Manufacturing Dam
# 1366        I95 Rest Area Lagoon Dam
# 1367          Silver Springs Dam #11
# 1368                   Riverside Dam
# 1369                 Hughesville Dam
# 1370                      Durham Dam
# 1371                  Reservoir 245B
# 1372                    Klondike Dam
# 1374                     Unnamed Dam
# 1375                Ward Dam Removal
# 1376                Kehena Reservoir
# 1377                  Hogansburg Dam
# 1378              Winton Springs Dam
# 1379                        Todd Dam
# 1380                Egypt Quarry Dam
# 1381         Santeetlah Fish Barrier
# 1382                   Schaaf #1 Dam
# 1383     Trexler Nature Preserve Dam
# 1384                     Foxtail Dam
# 1385           Silver Springs Dam #3
# 1386                 Oak Meadows Dam
# 1387  Sheridan Heights Reservoir Dam
# 1388            Upper Friendship Dam
# 1389             Wahikuli Reservoir
# 1390                     Midtown Dam
# 1391         Bacon Ridge Branch Weir
#
#                                                 dam_uri  \
# 0     https://www.sciencebase.gov/catalog/item/55fb4...
# 1     https://www.sciencebase.gov/catalog/item/55fb4...
# 2     https://www.sciencebase.gov/catalog/item/55fb4...
# 3     https://www.sciencebase.gov/catalog/item/55fb4...
# 4     https://www.sciencebase.gov/catalog/item/55fb4...
# 5     https://www.sciencebase.gov/catalog/item/55fb4...
# 6     https://www.sciencebase.gov/catalog/item/55fb4...
# 7     https://www.sciencebase.gov/catalog/item/55fb4...
# 8     https://www.sciencebase.gov/catalog/item/55fb4...
# 9     https://www.sciencebase.gov/catalog/item/55fb4...
# 10    https://www.sciencebase.gov/catalog/item/55fb4...
# 11    https://www.sciencebase.gov/catalog/item/55fb4...
# 12    https://www.sciencebase.gov/catalog/item/55fb4...
# 13    https://www.sciencebase.gov/catalog/item/55fb4...
# 14    https://www.sciencebase.gov/catalog/item/55fb4...
# 15    https://www.sciencebase.gov/catalog/item/55fb4...
# 16    https://www.sciencebase.gov/catalog/item/55fb4...
# 17    https://www.sciencebase.gov/catalog/item/55fb4...
# 18    https://www.sciencebase.gov/catalog/item/55fb4...
# 19    https://www.sciencebase.gov/catalog/item/55fb4...
# 20    https://www.sciencebase.gov/catalog/item/55fb4...
# 21    https://www.sciencebase.gov/catalog/item/55fb4...
# 22    https://www.sciencebase.gov/catalog/item/55fb4...
# 23    https://www.sciencebase.gov/catalog/item/55fb4...
# 24    https://www.sciencebase.gov/catalog/item/55fb4...
# 25    https://www.sciencebase.gov/catalog/item/55fb4...
# 26    https://www.sciencebase.gov/catalog/item/55fb4...
# 27    https://www.sciencebase.gov/catalog/item/55fb4...
# 28    https://www.sciencebase.gov/catalog/item/55fb4...
# 29    https://www.sciencebase.gov/catalog/item/55fb4...
# ...                                                 ...
# 1360                                               None
# 1361                                               None
# 1362                                               None
# 1363                                               None
# 1364                                               None
# 1366                                               None
# 1367                                               None
# 1368                                               None
# 1369                                               None
# 1370                                               None
# 1371                                               None
# 1372                                               None
# 1374                                               None
# 1375                                               None
# 1376                                               None
# 1377                                               None
# 1378                                               None
# 1379                                               None
# 1380                                               None
# 1381                                               None
# 1382                                               None
# 1383                                               None
# 1384                                               None
# 1385                                               None
# 1386                                               None
# 1387                                               None
# 1388                                               None
# 1389                                               None
# 1390                                               None
# 1391                                               None
#
#                                 identifier  inDrd  \
# 0     9cddf5d4-89b7-4d11-95d2-ca75bffa96c9      1
# 1     1b72adcb-3d13-43b4-89a3-e87b46cf0517      1
# 2     57093f00-3f8a-4bf4-8e6c-0dc893986a9b      1
# 3     b3224aae-5b74-4b71-aa73-cef90cc505dd      1
# 4     504c142f-36f8-4f8c-98ce-52a099e3d4a9      1
# 5     bc452c50-30b3-40c1-88c0-86ecc4ba19f3      1
# 6     bd3bdc3f-b724-4f2a-8f91-5e8c4d825d28      1
# 7     ae786fdb-c068-4f52-ac9a-cbdf71385e30      1
# 8     9dcd13c6-a1dc-4042-be62-e30223e0cada      1
# 9     0b771582-010e-42d9-bb10-da0e612a8e18      1
# 10    25947443-7599-468e-822f-e7a6212b6d0b      1
# 11    71241de2-2274-4644-a01b-af80126cbe2b      1
# 12    918505b0-c019-47d8-8158-ae733ebfb36e      1
# 13    b848dbc0-ceb5-4e6c-8654-65f5558d7623      1
# 14    d2984ca5-8b2f-4107-9cc5-e172971815ab      1
# 15    6732f418-bdd3-4b1b-ae8f-ec2cadf0fe90      1
# 16    1a3e9db5-096f-4de3-b545-59efafc9b4cc      1
# 17    2caae7a7-75e5-4aea-ab2f-f596538c7447      1
# 18    4067f3bb-bd68-480e-b7de-f788b26749fd      1
# 19    8ba60885-eaa0-4048-a4b9-6057433a7099      1
# 20    d4aebe70-a22a-4f00-8d4b-fb043b1b5863      1
# 21    74cc9b77-5421-4281-b6df-d4894d6d4caa      1
# 22    5a0ed1ae-b97e-4425-ac37-6d8a845d77b9      1
# 23    db4c7669-4f13-4fb9-9f1c-80301530e3e7      1
# 24    5301915e-c925-4760-b514-a03b87d0408d      1
# 25    d8b96150-9858-4e5f-88f1-81a5787f5c97      1
# 26    ca965547-90ef-48ff-aa20-6d43cc0e183e      1
# 27    4d1e84db-72d5-40d3-bf44-b2d5bedd3930      1
# 28    070f22c4-ff68-41d9-aae4-7c16fe470f27      1
# 29    905dddcf-28d9-4dd0-8184-44558fa4dab3      1
# ...                                    ...    ...
# 1360  35fb536f-079b-41c9-8dd5-e7da030a65cf      0
# 1361  397b41f3-e9be-4a24-8fa2-4893b052547a      0
# 1362  38244b2e-ed5d-4042-b1db-257d577bb5d3      0
# 1363  b9a15fbb-2707-4de7-b763-6e7c41295b04      0
# 1364  aa23359a-4a5a-485a-a0aa-84251dd226d3      0
# 1366  1e60121d-8f61-4211-8058-8f47077bf6df      0
# 1367  fe1c5d66-c144-40fd-9e8f-eed1a4f52a95      0
# 1368  23090335-6787-4ea6-9483-79326ac10f1b      0
# 1369  1f2ec126-6be5-4168-adb0-17594743d26c      0
# 1370  a04c8c18-03fa-49e8-bc63-28ebba0d2623      0
# 1371  286f1756-f97e-475a-80a3-70214bcdd902      0
# 1372  01e39735-2f55-42c9-8f9a-58c747f7ed22      0
# 1374  6b0e628a-b157-4555-a383-3d99c3fd4d21      0
# 1375  b269f0f4-ae3d-411d-a9c6-2b8bcffdaf80      0
# 1376  965716bd-154b-4616-be73-de793247623c      0
# 1377  620a465d-3b79-4de7-b090-36fa4a5a3fe1      0
# 1378  f69135fd-b052-4324-8727-0803c228ddcc      0
# 1379  0f82f6df-a29c-4b77-a1d0-4b5d0b1bc01f      0
# 1380  860c9253-6524-4564-96e8-88c2aff3e05a      0
# 1381  e16027fc-5c0a-4e2d-a645-61764f72bf03      0
# 1382  c3762ec4-75f2-49b9-b37a-4582308593f7      0
# 1383  bf77ac67-d405-4cb0-9a6a-92478ba7c158      0
# 1384  60626b73-d86c-4047-a784-937735c8ee87      0
# 1385  340ab455-8b3e-4328-aa69-b8f556262bc3      0
# 1386  48d5868c-c527-4185-94b5-3af179a695db      0
# 1387  cfa9fff5-0918-44fc-92e7-0d8aca878312      0
# 1388  e73f62b1-fa23-478e-92b1-ce0e70b2d3d6      0
# 1389  00028048-1572-4557-9af7-a0c4d5c5b89e      0
# 1390  33ff3569-bbb4-422c-8b5e-fc8a95684da3      0
# 1391  9d976ef9-490e-4955-89e7-5bf1c2610de5      0
#
#                                   stream_name
# 0                                  Bass Creek
# 1                             Naugatuck River
# 2                        Pomme de Terre River
# 3                            Big Spring Creek
# 4                              Big Spring Run
# 5                           Black Earth Creek
# 6                               Boulder Creek
# 7                               Boulder Creek
# 8                                  Pine River
# 9                             Calapooia River
# 10                                 Deep River
# 11                                Muddy Creek
# 12                               Little River
# 13                              Sprague River
# 14                         White Salmon River
# 15                          Black Earth Creek
# 16                              Chipola River
# 17                             Brewster Creek
# 18                                 Mill Creek
# 19                           Tuckasegee River
# 20                               Dinner Creek
# 21
# 22                             Mountain Creek
# 23                             Kennebec River
# 24                                Elwha River
# 25                         Rappahannock River
# 26                               Salmon River
# 27                               Fossil Creek
# 28                               Middle Creek
# 29                           Otter Tail River
# ...                                       ...
# 1360
# 1361                              Muddy Brook
# 1362
# 1363                   Red River of the North
# 1364                                Big Creek
# 1366                 Tributary to Black Creek
# 1367                 Tributary to Onion River
# 1368                                Red River
# 1369                       Musconetcong River
# 1370                          Toppenish Creek
# 1371
# 1372                          Big Sioux River
# 1374                               Sims Creek
# 1375                              Mckay Creek
# 1376                                  Wainaia
# 1377                        Saint Regis River
# 1378
# 1379  Trinity River (East Fork of North Fork)
# 1380                             Coplay Creek
# 1381                               Santeetlah
# 1382
# 1383                             Jordan Creek
# 1384
# 1385                 Tributary to Onion River
# 1386                               Salt Creek
# 1387            Tributary in City of Sheridan
# 1388
# 1389                          Honokohau Ditch
# 1390                   Red River of the North
# 1391                       Bacon Ridge Branch
#
# [1427 rows x 9 columns]

# %%
#Build a new table in GC2 if it doesn't already exist
q_createDripDams = "CREATE TABLE IF NOT EXISTS drip.dripdams( \
    _id varchar(40) primary key,\
    damBuiltYear int, \
    damRemovedYear int, \
    damHeight_ft float(6), \
    dam_name varchar(150), \
    stream_name varchar(150), \
    dam_uri varchar(80), \
    inDrd int)"
url_createDripDams = gc2.sqlAPI("datadistillery","bcb")+"&q="+q_createDripDams
print (requests.get(url_createDripDams,verify=False).json())
# Out:
# {'success': True, 'affected_rows': 0, '_execution_time': 0.024}
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
#Upload final dripdams table into GC2

# Set up the actions/targets for this particular instance
thisRun = {}
thisRun['instance'] = 'DataDistillery'
thisRun['db'] = 'BCB'
thisRun['baseURL'] = gc2.sqlAPI(thisRun['instance'],thisRun['db'])  #base url includes ?key
thisRun['schema'] = 'drip'
thisRun['commitToDB'] = False
thisRun['Table'] = 'dripdams'
thisRun['gc2Key'] = gc2.gc2Keys['datadistillery_bcb']  #Reads in api key, allowing for insert capabilities

q_recordToSearch = "SELECT _id as id from drip.dripdams1" 
recordToSearch = requests.get(gc2.baseURLs["sqlapi_datadistillery_bcb"]+"?q="+q_recordToSearch, verify=False).json()
p = recordToSearch['features']
lookup = []
for f in p:
    s = str(f['properties']['id'])
    lookup.append(s)

lenList = len(lookup)
cntExisting = 0 
existingList = []

for row in dripDf.itertuples():
    if row.identifier in lookup:
        continue
    else:
        identifier = str(row.identifier)
        #print (str(row.damRemovedYear))
        removed = str(row.damRemovedYear)
        if removed == 'nan':
            removed = 'null'
        height = str(row.damHeight_ft)   
        if height == 'nan':
            height = 'null'
        built = str(row.damBuiltYear)
        if built == 'nan':
            built = 'null'
        dam_name = str(row.dam_name)
        stream_name = str(row.stream_name)
        if stream_name == 'None' or stream_name == 'nan':
            stream_name = ' '
        dam_uri = str(row.dam_uri)
        if dam_uri == 'None' or dam_uri == 'nan':
            dam_uri = ' '
        inDrd = str(row.inDrd)
        
        q = "insert into drip.dripdams1(_id, damBuiltYear, damRemovedYear, damHeight_ft, \
        dam_name, stream_name, dam_uri, inDrd)\
        VALUES ('" + identifier + "' ,"  + built + " ," + removed + " ," + height + " ,'" + dam_name \
        + "' ,'" + stream_name + "' ,'" + dam_uri + "'," + inDrd + ")"
        payload = "q=%s&key=%s"%(q,thisRun['gc2Key'])
        #print (payload)
        url= gc2.baseURLs["sqlapi_datadistillery_bcb"]
        #print (url)
        
        try:
            r = requests.post(url,data=payload,verify=False)
            print (r)
        except:
            continue
# Out:
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# #Below here documents beta specific cells

# %%
#Retrieves Data for analytical units, Renders GEOJSON as Python object
queryAr = 'https://beta-gc2.datadistillery.org/api/v1/sql/bcb?q=select a._id as id, a.ar_id, a.year_built as arBuilt, a.year_removed as arRemoved, a.dam_height_ft, a.dam_name, a.river, b.featureuri from drip.ardamremoval a left join drip.dripSb b on a.ar_id = b.ar_id' 
rAr = requests.get(url=queryAr,verify=False)
queryDrd = 'https://beta-gc2.datadistillery.org/api/v1/sql/bcb?q=select a._id as id, a.ar_id, a.damyearbuiltoriginalstructure, a.damyearbuiltremovedstructure, a.damyearremovalfinished, a.damheight_m, a.damname, a.damrivername, b.featureuri from drip.drddamremovals a left join drip.dripsb b on a.damaccessionnumber=b.damaccessionnumber'
rDrd = requests.get(url=queryDrd,verify=False)

# %%
#Build a new table in GC2 if it doesn't already exist
q_createDripDams = "CREATE TABLE IF NOT EXISTS drip.dripdams( \
    _id varchar(40) primary key,\
    damBuiltYear int, \
    damRemovedYear int, \
    damHeight_ft float(6), \
    dam_name varchar(150), \
    stream_name varchar(150), \
    dam_uri varchar(80), \
    inDrd int)"
url_createDripDams = gc2.sqlAPI("datadistillery","bcb_beta")+"&q="+q_createDripDams
print (requests.get(url_createDripDams,verify=False).json())

# %%
# Set up the actions/targets for this particular instance


#BETA BETA BETA BETA BETA




thisRun = {}
thisRun['instance'] = 'DataDistillery'
thisRun['db'] = 'BCB_beta'
thisRun['baseURL'] = gc2.sqlAPI(thisRun['instance'],thisRun['db'])  #base url includes ?key
thisRun['schema'] = 'drip'
thisRun['commitToDB'] = False
thisRun['Table'] = 'drip_height_years'
thisRun['gc2Key'] = gc2.gc2Keys['datadistillery_bcb_beta']  #Reads in api key, allowing for insert capabilities

q_recordToSearch = "SELECT _id as id from drip.dripdams" 
recordToSearch = requests.get(gc2.baseURLs["sqlapi_datadistillery_bcb_beta"]+"?q="+q_recordToSearch, verify=False).json()
p = recordToSearch['features']
lookup = []
for f in p:
    s = str(f['properties']['id'])
    lookup.append(s)
lenList = len(lookup)
cntExisting = 0 
existingList = []

for row in dripDf.itertuples():
    if row.identifier in lookup:
        continue
    else:
        identifier = str(row.identifier)
        #print (str(row.damRemovedYear))
        removed = str(row.damRemovedYear)
        if removed == 'nan':
            removed = 'null'
        height = str(row.damHeight_ft)   
        if height == 'nan':
            height = 'null'
        built = str(row.damBuiltYear)
        if built == 'nan':
            built = 'null'
        dam_name = str(row.dam_name)
        stream_name = str(row.stream_name)
        if stream_name == 'None' or stream_name == 'nan':
            stream_name = ' '
        dam_uri = str(row.dam_uri)
        if dam_uri == 'None' or dam_uri == 'nan':
            dam_uri = ' '
        inDrd = str(row.inDrd)
        
        q = "insert into drip.dripdams(_id, damBuiltYear, damRemovedYear, damHeight_ft, \
        dam_name, stream_name, dam_uri, inDrd)\
        VALUES ('" + identifier + "' ,"  + built + " ," + removed + " ," + height + " ,'" + dam_name \
        + "' ,'" + stream_name + "' ,'" + dam_uri + "'," + inDrd + ")"
        payload = "q=%s&key=%s"%(q,thisRun['gc2Key'])
        print (payload)
        url= gc2.baseURLs["sqlapi_datadistillery_bcb_beta"]
        #print (url)
        
        try:
            r = requests.post(url,data=payload,verify=False)
            print (r)
        except:
            continue
